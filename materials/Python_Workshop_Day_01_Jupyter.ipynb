# %% [markdown]
# # Jupyter notebook
# Lecturers = R. Patrick Xian, Santosh Adhikari, Sourin Dey<br>
# Date = 07/2022
# ## 1. Notebook as development environment
# ### 1.1 Cell magic
# The [complete manual](http://ipython.readthedocs.io/en/stable/interactive/magics.html) and [some examples](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
a = [i**2 for i in range(1000000)]
# %timeit [i**2 for i in range(1000000)]
# Out:
# 929 ms ± 210 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np
b = np.arange(1000000, dtype='int64')**2
# %timeit np.arange(1000000, dtype='int64')**2
# Out:
# 8.85 ms ± 2.11 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
np.prod(a == b)
# Out:
# 1

# %%
a == b.tolist()
# Out:
# True

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          list       n=1000000
# b          ndarray    1000000: 1000000 elems, type `int64`, 8000000 bytes (7.62939453125 Mb)
# np         module     <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>

# %%
whos;
# Out:
# No variables match your requested type.

# %%
# %%latex
# $$i\hbar \frac{\partial \psi}{\partial t} = H\psi$$
# Out:
# $$i\hbar \frac{\partial \psi}{\partial t} = H\psi$$

# %%
# %%capture
print('Hello World!')

# %%
print??

# %%
# %%capture
# %history -n

# %%
c = [3, 4
# Out:
#   File "<ipython-input-12-821d8d719c80>", line 1
#     c = [3, 4
#              ^
# SyntaxError: unexpected EOF while parsing

# %%
# %debug
# Out:
# > c:\programdata\anaconda3\lib\site-packages\ipython\core\compilerop.py(100)ast_parse()
#      98         Arguments are exactly the same as ast.parse (in the standard library),
#      99         and are passed to the built-in compile function."""
# --> 100         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     101
#     102     def reset_compiler_flags(self):
#
# ipdb> up
# *** Oldest frame
# ipdb> bt
# > c:\programdata\anaconda3\lib\site-packages\ipython\core\compilerop.py(100)ast_parse()
#      98         Arguments are exactly the same as ast.parse (in the standard library),
#      99         and are passed to the built-in compile function."""
# --> 100         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     101
#     102     def reset_compiler_flags(self):
#
# ipdb> exit

# %%
denv = %env
denv['HOMEPATH'];

# %%
# %%writefile addall.py
#! /usr/bin/env python

def addalleven(arr):
    evens = [n for n in arr if n % 2 == 0]
    return sum(evens)
    
def addallodd(arr):
    odds = [n for n in arr if n % 2 == 1]
    return sum(evens)
# Out:
# Overwriting addall.py

# %%
# !cat addall.py
# Out:
# def addalleven(arr):
#     evens = [n for n in arr if n % 2 == 0]
#     return sum(evens)
#
# def addallodd(arr):
#     odds = [n for n in arr if n % 2 == 1]
#     return sum(evens)

# %%
import addall as aa
aa.addalleven([0,2,8,1,3])
# Out:
# 10

# %% [markdown]
# ### 1.2 [Notebook caching](http://ipython.org/ipython-doc/stable/interactive/reference.html#output-caching-system)

# %%
from math import sin, radians, isclose

# %%
A = radians(30)
A
# Out:
# 0.5235987755982988

# %%
B = radians(80)
B
# Out:
# 1.3962634015954636

# %%
C = radians(70)
C
# Out:
# 1.2217304763960306

# %%
isclose(sin(2*___) + sin(2*__) + sin(2*_), 4*sin(___)*sin(__)*sin(_), abs_tol=1e-12)
# Out:
# True

# %%
isclose(sin(2*A) + sin(2*B) + sin(2*C), 4*sin(A)*sin(B)*sin(C), abs_tol=1e-12)
# Out:
# True

# %%
In[13]
# Out:
# "get_ipython().magic('debug')"

# %%
Out[13]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-2196cfd47f53> in <module>()
# ----> 1 Out[13]
#
# KeyError: 13

# %% [markdown]
# ## 2. Notebook as terminal

# %%
# !ls
# Out:
# PyTutorial_01_Basics.ipynb
# PyTutorial_02_Jupyter.ipynb
# PyTutorial_03_Numerics.ipynb
# PyTutorial_04_Visualization.ipynb
# PyTutorial_05_AdvancedTopics.ipynb
# PyTutorial_06_NichePackages.ipynb
# TP.mat
# __pycache__
# addall.py

# %%
# !ls ..
# Out:
# README.md
# materials

# %%
# !pwd
# Out:
# /e/gitrepo/python_tutorial_FHI-PC-SESD/materials

# %%
files = !ls
notebooks = [f for f in files if f.endswith('.ipynb')]
notebooks
# Out:
# ['PyTutorial_01_Basics.ipynb',
#  'PyTutorial_02_Jupyter.ipynb',
#  'PyTutorial_03_Numerics.ipynb',
#  'PyTutorial_04_Visualization.ipynb',
#  'PyTutorial_05_AdvancedTopics.ipynb',
#  'PyTutorial_06_NichePackages.ipynb']

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 2.0.0
# Summary: Python plotting package
# Home-page: http://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: BSD
# Location: c:\programdata\anaconda3\lib\site-packages
# Requires: numpy, six, python-dateutil, pytz, cycler, pyparsing

# %%
# !python -V
# Out:
# Python 3.6.0 :: Anaconda custom (64-bit)

# %% [markdown]
# ## 3. Notebook as multimedia interface
# ### 3.1 Display image

# %%
import IPython.display as disp
fhi_pc_logo_url = 'https://storage.googleapis.com/thehundreds/media/2017/06/convergence-1.jpg'
pollock = disp.Image(url=fhi_pc_logo_url)
disp.display(pollock)
# Out:
# <img src="https://storage.googleapis.com/thehundreds/media/2017/06/convergence-1.jpg"/>

# %%
type(pollock)
# Out:
# IPython.core.display.Image

# %%
pollock.__dict__
# Out:
# {'format': 'jpeg',
#  'embed': False,
#  'width': None,
#  'height': None,
#  'retina': False,
#  'unconfined': False,
#  'url': 'https://storage.googleapis.com/thehundreds/media/2017/06/convergence-1.jpg',
#  'filename': None,
#  'data': None,
#  'metadata': {}}

# %%
from PIL import Image
import urllib.request
import io
import numpy as np

with urllib.request.urlopen(fhi_pc_logo_url) as url:
    imgfile = io.BytesIO(url.read())

img_pollock = Image.open(imgfile)
img_pollock.__dict__
# Out:
# {'im': None,
#  'mode': 'RGB',
#  '_size': (1100, 660),
#  'palette': None,
#  'info': {'jfif': 257,
#   'jfif_version': (1, 1),
#   'dpi': (240, 240),
#   'jfif_unit': 1,
#   'jfif_density': (240, 240),
# ...

# %%
pollock_data = np.asarray(img_pollock)
pollock_data.shape
# Out:
# (660, 1100, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
f, axs = plt.subplots(2, 2, figsize=(16, 10))
axs[0,0].imshow(pollock_data)
axs[0,0].axis('off')
axs[0,1].imshow(pollock_data[...,0], cmap='Reds')
axs[0,1].axis('off')
axs[1,0].imshow(pollock_data[...,1], cmap='Greens')
axs[1,0].axis('off')
axs[1,1].imshow(pollock_data[...,2], cmap='Blues')
axs[1,1].axis('off')

plt.subplots_adjust(wspace=0.05, hspace=0.05)

# %% [markdown]
# ### 3.2 Display video

# %%
disp.YouTubeVideo('YgtL4S7Hrwo')

# %% [markdown]
# ### 3.3 Display website

# %%
disp.IFrame('https://www.wired.com/', width='100%', height=600)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="https://www.wired.com/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
dir(disp)
# Out:
# ['Audio',
#  'Code',
#  'DisplayHandle',
#  'DisplayObject',
#  'FileLink',
#  'FileLinks',
#  'GeoJSON',
#  'HTML',
#  'IFrame',
#  'Image',
#  'JSON',
#  'Javascript',
#  'Latex',
#  'Markdown',
#  'Math',
#  'Pretty',
#  'ProgressBar',
#  'SVG',
#  'ScribdDocument',
#  'TextDisplayObject',
#  'Video',
#  'VimeoVideo',
#  'YouTubeVideo',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'clear_output',
#  'display',
#  'display_html',
#  'display_javascript',
#  'display_jpeg',
#  'display_json',
#  'display_latex',
#  'display_markdown',
#  'display_pdf',
#  'display_png',
#  'display_pretty',
#  'display_svg',
#  'publish_display_data',
#  'set_matplotlib_close',
#  'set_matplotlib_formats',
#  'update_display']
